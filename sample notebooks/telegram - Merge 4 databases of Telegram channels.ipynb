# %% [markdown]
# #### Guidelines
#
# iPhython kernel: Environment (mysite-viertualenv)
#
# Sample input: /home/devrazdev/sample_input/...
#
# Main function should take a list of paths to input files, create a report and then return a path to it.
#
# Best practices:
# - read/write data using pd.DataFrame objects
# - keep function names organized:
#     - **create_REPORT-NAME_report (pathsList):** main function
#     - **convert_TEMPLATE-NAME_template (path, outputColumnNames):** convert one of input files
#     - **convert_TEMPLATE-NAME_PARAMETER (parameterValue):** convert some tricky format (date, for ex.)

# %%
import os
from os import listdir
from os.path import isfile, join

import sys

import datetime
import pandas as pd
import numpy as np
import re

import string
import random

# %%
inputFolder = os.path.expanduser('~') + "/sample_input/telegram"

#to work with all files in the input folder
inputFiles = [join(inputFolder, f) for f in listdir(inputFolder) if isfile(join(inputFolder, f))]

# %%
for filePath in inputFiles:
    revPath = str(filePath)[::-1]
    revFileName = revPath[:revPath.find("/")]
    fileName = revFileName[::-1]
    
    df = pd.read_excel(filePath, sheet_name=0, encoding = 'utf-8', index=False)
    
    if "tchannels" in fileName:
        df_tchannels = df
        tchannels_list = df_tchannels[["resultId"]].applymap(lambda x: x.replace("@","").lower()).drop_duplicates()
        tchannels_list.columns = ["channel"]
        tchannels_list["tchannels"] = 1

    if "tlgrm" in fileName:
        df_tlgrm = df
        tlgrm_list = df_tlgrm[["resultId"]].applymap(lambda x: x.replace("@","").lower()).drop_duplicates()
        tlgrm_list.columns = ["channel"]
        tlgrm_list["tlgrm"] = 1

    if "tsearch" in fileName:
        df_tsearch = df
        tsearch_list = df_tsearch[["resultId"]].applymap(lambda x: x.replace("@","").lower()).drop_duplicates()
        tsearch_list.columns = ["channel"]
        tsearch_list["tsearch"] = 1

    if "intento" in fileName:
        df_intento = df
        intento_list = df_intento[["channel id"]].applymap(lambda x: x.replace("@","").lower()).drop_duplicates()
        intento_list.columns = ["channel"]
        intento_list["intento"] = 1

# %%
df_concatenated = pd.DataFrame(pd.concat([tchannels_list, tlgrm_list, tsearch_list, intento_list], sort=True)["channel"]).drop_duplicates()

# %%
df_merged = df_concatenated.merge(tchannels_list, on='channel', how='left').merge(tlgrm_list, on='channel', how='left').merge(tsearch_list, on='channel', how='left').merge(intento_list, on='channel', how='left')

# %%
df_filtered = df_merged.replace(np.nan, '', regex=True)

# %%
#df_filtered.loc[df_filtered['source 1'] == "tchannels"][df_filtered['source 2'] == "tlgrm"].shape[0]
df_filtered
# Out:
#                       channel tchannels tlgrm tsearch intento
# 0                         007         1
# 1           1freerideeveryday         1
# 2                    2827hshs         1
# 3                  987gwgwhso         1
# 4                        9gag         1
# 5                       a7zzz         1
# 6                   a_fishing         1
# 7                   a_navalny         1
# 8                      a_trtr         1
# 9      aaaaaecg2psftkggliazoa         1
# 10     aaaaaej1c2k14tehv5bwvq         1
# 11                   aaaanime         1
# 12                      abaev         1
# 13                 aban_place         1
# 14                     abbsol         1     1       1
# 15               abook_clubru         1
# 16                 about_maps         1
# 17             about_telegram         1
# 18               aboutandroid         1
# 19          aboutfamouspeople         1
# 20                    abouthr         1             1
# 21                 aboutmoney         1     1
# 22                aboutmoscow         1     1       1
# 23                 aboutmovie         1     1       1       1
# 24                absurdprice         1
# 25            abuldyginaphoto         1     1
# 26      abuldyginaphotography         1
# 27          abuyusuf_official         1
# 28               academyofman         1             1
# 29                   acdofman         1
# ...                       ...       ...   ...     ...     ...
# 10245                xexeclub                               1
# 10246                xiaomitg                               1
# 10247           xit_mp3_audio                               1
# 10248                xivasity                               1
# 10249                  xolism                               1
# 10250            xray_project                               1
# 10251          xuliganka_uzbe                               1
# 10252                 xusenof                               1
# 10253               xxxbattle                               1
# 10254                 yagamer                               1
# 10255               yasii_nek                               1
# 10256                   yayay                               1
# 10257               yellowrzd                               1
# 10258           yellowstarvpn                               1
# 10259        yes_we_can_do_it                               1
# 10260                  yoba_m                               1
# 10261            youngbloodvh                               1
# 10262           youngpolitics                               1
# 10263              yourproger                               1
# 10264             youtube_smm                               1
# 10265                  yoyma3                               1
# 10266                yurtimuz                               1
# 10267               zabbixpro                               1
# 10268              zamonarano                               1
# 10269       zayn_onedirection                               1
# 10270                  zdacha                               1
# 10271              zlayapizda                               1
# 10272             zlooifriend                               1
# 10273                znnkn_jk                               1
# 10274                  zor_tv                               1
#
# [10275 rows x 5 columns]
